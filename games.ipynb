# %%
import pandas as pd
import numpy as np
import customfunctions as cf

# %% [markdown]
# # Google Play Store Apps Info
# > From this [KaggleDatasets](https://kaggle.com/gauthamp10/google-playstore-apps?utm_medium=social&utm_campaign=kaggle-dataset-share&utm_source=twitter)

# %%
df_PlayStore = pd.read_csv('google-playstore-apps/Google-Playstore-Full.csv')

# columns with most NaN cells
Uncolumns = ['Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13','Unnamed: 14']

df_PlayStore = cf.deleteSomeColumns(Uncolumns,df_PlayStore )

df_PlayStore.head()
# Out:
# /home/naftalima/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (2,3,11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             App Name          Category  \
# 0                           DoorDash - Food Delivery    FOOD_AND_DRINK
# 1  TripAdvisor Hotels Flights Restaurants Attract...  TRAVEL_AND_LOCAL
# 2                                             Peapod          SHOPPING
# 3                    foodpanda - Local Food Delivery    FOOD_AND_DRINK
# 4                          My CookBook Pro (Ad Free)    FOOD_AND_DRINK
#
#         Rating      Reviews      Installs                Size  Price  \
# 0  4.548561573       305034    5,000,000+  Varies with device      0
# 1  4.400671482  1.20792e+06  100,000,000+  Varies with device      0
# 2  3.656329393         1967      100,000+                1.4M      0
# 3  4.107232571       389154   10,000,000+                 16M      0
# 4  4.647752285         2291       10,000+  Varies with device  $5.99
#
#   Content Rating        Last Updated     Minimum Version      Latest Version
# 0       Everyone      March 29, 2019  Varies with device  Varies with device
# 1       Everyone      March 29, 2019  Varies with device  Varies with device
# 2       Everyone  September 20, 2018          5.0 and up               2.2.0
# 3       Everyone      March 22, 2019          4.2 and up              4.18.2
# 4       Everyone       April 1, 2019  Varies with device  Varies with device

# %% [markdown]
# # Only Games

# %%
games = cf.categoryOnly(df_PlayStore,"GAME")
print(games)
# Out:
# ['GAME_ACTION', 'GAME_CASUAL', 'GAME_ROLE_PLAYING', 'GAME_PUZZLE', 'GAME_RACING', 'GAME_ADVENTURE', 'GAME_ARCADE', 'GAME_STRATEGY', 'GAME_SPORTS', 'GAME_SIMULATION', 'GAME_MUSIC', 'GAME_EDUCATIONAL', 'GAME_WORD', 'GAME_TRIVIA', 'GAME_BOARD', 'GAME_CASINO', 'GAME_CARD']

# %%
df_Games = cf.dfOnly(df_PlayStore,games )
print(cf.sizeRows(df_Games))
# Out:
# 22508.0

# %% [markdown]
# # Only Free Games

# %%
df_Games = cf.FreeGames(df_Games)
print(cf.sizeRows(df_Games))
# Out:
# 19586.0

# %%
df_Games
# Out:
#                                    App Name     Category       Rating Reviews  \
# 0                             King of Crabs  GAME_ACTION  3.280254841     785
# 1                          FRAG Pro Shooter  GAME_ACTION  4.510839939   76662
# 2                      Super Brawl Universe  GAME_ACTION  3.789777994    6398
# 3                Mountain Sniper 3D Shooter  GAME_ACTION  4.065671444     670
# 4                       Football Field Kick  GAME_ACTION          4.5     564
# ...                                     ...          ...          ...     ...
# 22503                    Advanced Solitaire    GAME_CARD            5       2
# 22504                          Canasta Plus    GAME_CARD      4.15827     139
# 22505                      Pinochle Classic    GAME_CARD         4.75       4
# 22506                            Phom T� L?    GAME_CARD       3.8727     652
# 22507  Burraco Pi� - Giochi di Carte Social    GAME_CARD      4.07857     840
#
#          Installs                Size Price Content Rating  \
# 0        500,000+                 72M     0   Everyone 10+
# 1      5,000,000+                 99M     0           Teen
# 2        500,000+                 58M     0   Everyone 10+
# 3        100,000+                 64M     0           Teen
# 4         50,000+                 24M     0       Everyone
# ...           ...                 ...   ...            ...
# 22503         50+                3.6M     0       Everyone
# 22504      5,000+                 15M     0           Teen
# 22505         50+                9.0M     0       Everyone
# 22506    100,000+  Varies with device     0           Teen
# 22507     10,000+                 28M     0       Everyone
#
#              Last Updated Minimum Version      Latest Version
# 0           March 7, 2019      4.4 and up               1.0.8
# 1          March 21, 2019      4.3 and up               1.3.4
# 2          March 25, 2019      4.4 and up                2.05
# 3          March 29, 2019    4.0.3 and up                 0.5
# 4          March 29, 2019      4.0 and up                1.05
# ...                   ...             ...                 ...
# 22503   November 20, 2018      4.0 and up                 1.1
# 22504      March 14, 2019      4.1 and up                 2.1
# 22505      March 20, 2019      4.0 and up                 1.1
# 22506     August 30, 2018      4.1 and up  Varies with device
# 22507  September 13, 2018    4.0.3 and up               1.6.0
#
# [19586 rows x 11 columns]

# %% [markdown]
# # Most Popular Free Games

# %%
# def qtdInstalls(df_Games):
#     dictInstall = {}
#     for i in df_Games['Installs']:
#         if i in dictInstall:
#             dictInstall[i] +=1
#         else:
#             dictInstall[i] = 1
#     print(dictInstall)
#
# qtdInstalls(df_Games)

df_Games.Installs.value_counts()
# Out:
# 1,000,000+        3329
# 100,000+          3258
# 10,000+           2308
# 1,000+            1762
# 500,000+          1575
# 10,000,000+       1239
# 100+              1153
# 50,000+           1153
# 5,000,000+        1098
# 5,000+             881
# 500+               646
# 10+                458
# 50+                345
# 50,000,000+        178
# 100,000,000+        90
# 5+                  65
# 1+                  36
# 500,000,000+         6
# 0+                   5
# 1,000,000,000+       1
# Name: Installs, dtype: int64

# %%
df_GamesSort = cf.popularOrder(df_Games)

# %%
df_GamesSort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19586 entries, 10406 to 5745
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   App Name         19586 non-null  object
#  1   Category         19586 non-null  object
#  2   Rating           19586 non-null  object
#  3   Reviews          19586 non-null  object
#  4   Installs         19586 non-null  int64
#  5   Size             19586 non-null  object
#  6   Price            19586 non-null  object
#  7   Content Rating   19586 non-null  object
#  8   Last Updated     19586 non-null  object
#  9   Minimum Version  19586 non-null  object
#  10  Latest Version   19586 non-null  object
#  11  Installs_clean   19586 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.9+ MB

# %%
df_GamesSort.Installs.value_counts()
# Out:
# 1000000       3329
# 100000        3258
# 10000         2308
# 1000          1762
# 500000        1575
# 10000000      1239
# 50000         1153
# 100           1153
# 5000000       1098
# 5000           881
# 500            646
# 10             458
# 50             345
# 50000000       178
# 100000000       90
# 5               65
# 1               36
# 500000000        6
# 0                5
# 1000000000       1
# Name: Installs, dtype: int64

# %%
df_GamesSort
# Out:
#                                          App Name          Category  \
# 10406                              Subway Surfers       GAME_ARCADE
# 51                                   Temple Run 2       GAME_ACTION
# 1510                                          Pou       GAME_CASUAL
# 8632                            Hill Climb Racing       GAME_RACING
# 1536                               My Talking Tom       GAME_CASUAL
# ...                                           ...               ...
# 2297                                   Vadaa Hunt       GAME_CASUAL
# 1033                              Best Air Hunter       GAME_ACTION
# 17812                                      RC Bot  GAME_EDUCATIONAL
# 18917  4 Only Jotto: The 4 Letter Logic Word Game         GAME_WORD
# 5745                               Bubble Shooter       GAME_PUZZLE
#
#             Rating      Reviews    Installs                Size Price  \
# 10406  4.498130798  2.98348e+07  1000000000                 85M     0
# 51     4.329188824  8.61282e+06   500000000  Varies with device     0
# 1510   4.330340385  1.07523e+07   500000000                 24M     0
# 8632   4.440124512  9.25786e+06   500000000                 64M     0
# 1536    4.49166584  1.55692e+07   500000000  Varies with device     0
# ...            ...          ...         ...                 ...   ...
# 2297   2.333333254            3           0                 20M     0
# 1033             5           24           0                7.2M     0
# 17812            3            4           0                3.1M     0
# 18917            5            1           0                1.5M     0
# 5745    4.13043499           23           0                 19M     0
#
#       Content Rating      Last Updated Minimum Version Latest Version  \
# 10406   Everyone 10+     March 7, 2019      4.1 and up        1.100.0
# 51          Everyone    March 27, 2019      4.1 and up         1.55.3
# 1510        Everyone      May 25, 2018      4.0 and up         1.4.77
# 8632        Everyone    March 19, 2019      4.2 and up         1.41.0
# 1536        Everyone     April 2, 2019      4.1 and up      5.2.3.326
# ...              ...               ...             ...            ...
# 2297        Everyone  December 5, 2018      4.4 and up          1.0.4
# 1033        Everyone     March 6, 2019      2.3 and up            1.2
# 17812       Everyone  November 1, 2018      4.4 and up              1
# 18917       Everyone  January 20, 2019      5.0 and up              1
# 5745        Everyone  October 23, 2018      4.0 and up          1.0.0
#
#       Installs_clean
# 10406     1000000000
# 51         500000000
# 1510       500000000
# 8632       500000000
# 1536       500000000
# ...              ...
# 2297               0
# 1033               0
# 17812              0
# 18917              0
# 5745               0
#
# [19586 rows x 12 columns]
